# %%
import pandas as pd
import json
import requests

# %%
def getDataFromProperty(city, state, prop_type):
    url = "https://us-real-estate.p.rapidapi.com/v2/for-sale?format=json"
    
    querystring = {
    "city": 'Phoenix',
    "limit": "200",
    "offset": "0",
    "beds_min":"1",
    "baths_min":"1",
    "lot_size_min":"1",
    "state_code": 'AZ',
    "property_type": 'sing_family',
    }
    
    headers = {
        'x-rapidapi-host': "us-real-estate.p.rapidapi.com",
        'x-rapidapi-key': "21cf76b74dmsh389657fadba1640p1eb3d5jsnf826661c2576"
        }
    
json_data = requests.get(url, headers = headers, params = querystring).json()
json_data = json_data['data']['home_search']['results']

# %%
#print(json.dumps(json_data, indent=4, sort_keys=True))

# %%
#dictionary of desired values
houses = {'city': [],
         'zipcode': [],
         'state': [],
         'county': [],
         'longitude': [],
         'latitude': [],
         'sqft': [],
        }

#populate dict values and append to list
for house in json_data:
    houses['city'].append(house['location']['address']['city'])
    houses['zipcode'].append(house['location']['address']['postal_code'])
    houses['state'].append(house['location']['address']['state'])
    houses['county'].append(house['location']['county']['name'])
    houses['longitude'].append(house['location']['address']['coordinate']['lon'])
    houses['latitude'].append(house['location']['address']['coordinate']['lat'])
    houses['sqft'].append(house['description']['sqft'])
    #house_list.append(houses)
    


print(houses)
# Out:
# {'city': ['Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Tolleson', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Glendale', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Glendale', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Scottsdale', 'Glendale', 'Scottsdale', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix'], 'zipcode': ['85041', '85032', '85014', '85033', '85353', '85033', '85035', '85017', '85040', '85308', '85019', '85037', '85019', '85017', '85029', '85006', '85015', '85041', '85017', '85023', '85306', '85009', '85015', '85035', '85008', '85024', '85086', '85032', '85013', '85016', '85029', '85254', '85308', '85254', '85018', '85012', '85086', '85044', '85009', '85054', '85003', '85018'], 'state': ['Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona'], 'county': ['Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa'], 'longitude': [-112.084176, -112.005985, -112.060858, -112.193642, -112.261197, -112.228444, -112.162264, -112.124475, -111.984748, -112.155717, -112.135656, -112.286687, -112.137434, -112.132935, -112.091481, -112.054512, -112.10485, -112.120558, -112.115328, -112.086601, -112.164705, -112.150755, -112.093221, -112.154302, -111.981288, -112.058548, -112.069052, -112.002951, -112.076567, -112.033653, -112.128957, -111.97186, -112.153583, -111.97647, -111.9988, -112.073212, -112.138377, -111.991454, -112.129357, -111.965968, -112.076767, -111.984439], 'latitude': [33.410545, 33.635829, 33.518437, 33.503986, 33.411064, 33.506803, 33.466658, 33.522019, 33.394622, 33.65337, 33.52644, 33.501242, 33.521707, 33.521258, 33.584561, 33.475948, 33.499124, 33.380989, 33.51834, 33.609471, 33.612467, 33.473791, 33.53062, 33.475593, 33.470868, 33.658128, 33.869412, 33.610222, 33.532016, 33.504754, 33.586168, 33.584497, 33.653347, 33.635774, 33.491217, 33.485126, 33.839077, 33.332612, 33.445219, 33.679444, 33.460546, 33.519608], 'sqft': [2352, 1249, 1893, 2336, 1718, 1508, 1605, 1180, 1898, 2722, 1350, 2107, 1591, 1843, 740, 1338, 1100, 2595, 1701, 7710, 698, 1511, 2969, 1638, 1922, 2663, 1978, 1264, 1640, 1517, 1430, 693, 1794, 2796, 1476, 1109, 2168, 1273, 2520, 2265, 1431, 2386]}


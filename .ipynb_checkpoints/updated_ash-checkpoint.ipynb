# %%
import pandas as pd
import json
import requests

# %%
#def getDataFromProperty(city, state, prop_type):
url = "https://us-real-estate.p.rapidapi.com/v2/for-sale?format=json"
    
querystring = {
    "city": 'Phoenix',
    "limit": "200",
    "offset": "0",
    "beds_min":"1",
    "baths_min":"1",
    "lot_size_min":"1",
    "state_code": 'AZ',
    "property_type": 'sing_family',
    }
    
headers = {
        'x-rapidapi-host': "us-real-estate.p.rapidapi.com",
        'x-rapidapi-key': "21cf76b74dmsh389657fadba1640p1eb3d5jsnf826661c2576"
        }
    
json_data = requests.get(url, headers = headers, params = querystring).json()
json_data = json_data['data']['home_search']['results']

# %%
#print(json.dumps(json_data, indent=4, sort_keys=True))

# %%
#dictionary of desired values
houses = {'city': [],
         'zipcode': [],
         'state': [],
         'county': [],
         'longitude': [],
         'latitude': [],
         'sqft': [],
         #'primary_photo': [],
         'beds': [],
         'baths': [],
        }

#populate dict values and append to list
for house in json_data:
    houses['city'].append(house['location']['address']['city'])
    houses['zipcode'].append(house['location']['address']['postal_code'])
    houses['state'].append(house['location']['address']['state'])
    houses['county'].append(house['location']['county']['name'])
    houses['longitude'].append(house['location']['address']['coordinate']['lon'])
    houses['latitude'].append(house['location']['address']['coordinate']['lat'])
    houses['sqft'].append(house['description']['sqft'])
    houses['beds'].append(house['description']['beds'])
    houses['baths'].append(house['description']['baths'])
    #house_list.append(houses)
    


print(houses)
# Out:
# {'city': ['Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Tolleson', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Scottsdale', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix', 'Phoenix'], 'zipcode': ['85023', '85029', '85023', '85009', '85019', '85021', '85040', '85023', '85043', '85014', '85353', '85037', '85015', '85051', '85032', '85020', '85027', '85041', '85051', '85029', '85013', '85028', '85009', '85017', '85053', '85041', '85016', '85009', '85016', '85007', '85024', '85042', '85014', '85021', '85006', '85006', '85254', '85054', '85050', '85016', '85018', '85018'], 'state': ['Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona'], 'county': ['Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa', 'Maricopa'], 'longitude': [-112.097518, -112.086854, -112.098755, -112.10228, -112.150718, -112.109062, -112.036159, -112.098999, -112.195911, -112.052785, -112.28893, -112.244275, -112.092912, -112.135482, -112.02033, -112.073341, -112.106781, -112.112316, -112.146761, -112.104512, -112.085118, -111.995319, -112.132412, -112.119906, -112.122857, -112.080097, -112.025174, -112.101526, -112.016203, -112.097254, -112.035258, -112.043821, -112.056739, -112.094826, -112.043152, -112.048682, -111.969286, -111.934708, -111.99432, -112.015674, -112.00609, -111.972185], 'latitude': [33.628403, 33.607196, 33.628593, 33.468227, 33.485464, 33.561279, 33.396557, 33.626489, 33.432288, 33.536309, 33.410985, 33.501666, 33.516404, 33.559769, 33.628195, 33.557808, 33.661715, 33.383907, 33.554517, 33.606034, 33.507823, 33.584758, 33.465285, 33.506297, 33.624167, 33.390566, 33.494266, 33.480371, 33.512283, 33.452974, 33.702812, 33.371589, 33.537522, 33.56651, 33.464018, 33.467835, 33.635489, 33.647809, 33.655931, 33.512914, 33.51252, 33.487677], 'sqft': [1024, 1610, 900, 735, 1430, 1362, 2024, 1024, 1058, 2100, 2802, 1500, 896, 1035, 1110, 952, 2118, 1685, 1814, 2016, 1514, 2044, 1500, 1452, 1262, 1334, 655, 1835, 957, 1251, 1645, 2685, 1317, 1347, 1048, 1844, 2106, 1138, 1379, 1073, 3763, 2220], 'beds': [3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 2, 2, 3, 2, 3, 4, 3, 4, 4, 4, 3, 3, 3, 3, 1, 3, 1, 2, 4, 4, 3, 3, 3, 4, 4, 1, 3, 1, 5, 3], 'baths': [2, 2, 2, 3, 2, 2, 3, 2, 2, 2, 3, 2, 2, 2, 2, 2, 2, 2, 2, 3, 3, 2, 1, 2, 2, 2, 1, 2, 1, 2, 2, 3, 2, 2, 1, 3, 2, 2, 3, 1, 4, 2]}

# %%
houses_df = pd.DataFrame.from_dict(houses)
houses_df
# Out:
#           city zipcode    state    county   longitude   latitude  sqft  beds  \
# 0      Phoenix   85023  Arizona  Maricopa -112.097518  33.628403  1024     3
# 1      Phoenix   85029  Arizona  Maricopa -112.086854  33.607196  1610     3
# 2      Phoenix   85023  Arizona  Maricopa -112.098755  33.628593   900     3
# 3      Phoenix   85009  Arizona  Maricopa -112.102280  33.468227   735     3
# 4      Phoenix   85019  Arizona  Maricopa -112.150718  33.485464  1430     3
# 5      Phoenix   85021  Arizona  Maricopa -112.109062  33.561279  1362     3
# 6      Phoenix   85040  Arizona  Maricopa -112.036159  33.396557  2024     3
# 7      Phoenix   85023  Arizona  Maricopa -112.098999  33.626489  1024     3
# 8      Phoenix   85043  Arizona  Maricopa -112.195911  33.432288  1058     3
# 9      Phoenix   85014  Arizona  Maricopa -112.052785  33.536309  2100     4
# 10    Tolleson   85353  Arizona  Maricopa -112.288930  33.410985  2802     3
# 11     Phoenix   85037  Arizona  Maricopa -112.244275  33.501666  1500     3
# 12     Phoenix   85015  Arizona  Maricopa -112.092912  33.516404   896     2
# 13     Phoenix   85051  Arizona  Maricopa -112.135482  33.559769  1035     2
# 14     Phoenix   85032  Arizona  Maricopa -112.020330  33.628195  1110     3
# 15     Phoenix   85020  Arizona  Maricopa -112.073341  33.557808   952     2
# 16     Phoenix   85027  Arizona  Maricopa -112.106781  33.661715  2118     3
# 17     Phoenix   85041  Arizona  Maricopa -112.112316  33.383907  1685     4
# 18     Phoenix   85051  Arizona  Maricopa -112.146761  33.554517  1814     3
# 19     Phoenix   85029  Arizona  Maricopa -112.104512  33.606034  2016     4
# 20     Phoenix   85013  Arizona  Maricopa -112.085118  33.507823  1514     4
# 21     Phoenix   85028  Arizona  Maricopa -111.995319  33.584758  2044     4
# 22     Phoenix   85009  Arizona  Maricopa -112.132412  33.465285  1500     3
# 23     Phoenix   85017  Arizona  Maricopa -112.119906  33.506297  1452     3
# 24     Phoenix   85053  Arizona  Maricopa -112.122857  33.624167  1262     3
# 25     Phoenix   85041  Arizona  Maricopa -112.080097  33.390566  1334     3
# 26     Phoenix   85016  Arizona  Maricopa -112.025174  33.494266   655     1
# 27     Phoenix   85009  Arizona  Maricopa -112.101526  33.480371  1835     3
# 28     Phoenix   85016  Arizona  Maricopa -112.016203  33.512283   957     1
# 29     Phoenix   85007  Arizona  Maricopa -112.097254  33.452974  1251     2
# 30     Phoenix   85024  Arizona  Maricopa -112.035258  33.702812  1645     4
# 31     Phoenix   85042  Arizona  Maricopa -112.043821  33.371589  2685     4
# 32     Phoenix   85014  Arizona  Maricopa -112.056739  33.537522  1317     3
# 33     Phoenix   85021  Arizona  Maricopa -112.094826  33.566510  1347     3
# 34     Phoenix   85006  Arizona  Maricopa -112.043152  33.464018  1048     3
# 35     Phoenix   85006  Arizona  Maricopa -112.048682  33.467835  1844     4
# 36  Scottsdale   85254  Arizona  Maricopa -111.969286  33.635489  2106     4
# 37     Phoenix   85054  Arizona  Maricopa -111.934708  33.647809  1138     1
# 38     Phoenix   85050  Arizona  Maricopa -111.994320  33.655931  1379     3
# 39     Phoenix   85016  Arizona  Maricopa -112.015674  33.512914  1073     1
# 40     Phoenix   85018  Arizona  Maricopa -112.006090  33.512520  3763     5
# 41     Phoenix   85018  Arizona  Maricopa -111.972185  33.487677  2220     3
#
#     baths
# 0       2
# 1       2
# 2       2
# 3       3
# 4       2
# 5       2
# 6       3
# 7       2
# 8       2
# 9       2
# 10      3
# 11      2
# 12      2
# 13      2
# 14      2
# 15      2
# 16      2
# 17      2
# 18      2
# 19      3
# 20      3
# 21      2
# 22      1
# 23      2
# 24      2
# 25      2
# 26      1
# 27      2
# 28      1
# 29      2
# 30      2
# 31      3
# 32      2
# 33      2
# 34      1
# 35      3
# 36      2
# 37      2
# 38      3
# 39      1
# 40      4
# 41      2

# %%
print('How many beds?')
if houses_df['beds'] == 1:
    print([19][23])
else:
    print('hi')
# Out:
# How many beds?
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/2f/cdvmspms4d35h8l4mp1n2f900000gn/T/ipykernel_16968/3123349738.py in <module>
#       1 print('How many beds?')
# ----> 2 if houses_df['beds'] == 1:
#       3     print([19][23])
#       4 else:
#       5     print('hi')
#
# /opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1536     def __nonzero__(self):
#    1537         raise ValueError(
# -> 1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1540         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
bedrooms = int(input("How many bedrooms are you looking for?"))
filtered_df = houses_df.loc[houses_df["beds"]==bedrooms]
filtered_df

# %%
sqft = int(input("How many square feet are you looking for?"))
filtered_df = houses_df.loc[houses_df["sqft"]>sqft]
filtered_df
